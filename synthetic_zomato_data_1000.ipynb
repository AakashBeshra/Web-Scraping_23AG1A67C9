# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
df = pd.read_csv('/content/synthetic_zomato_data_1000.csv')
df.describe()
# Out:
#        Aggregate_Rating        Votes         Cost
# count       1000.000000  1000.000000  1000.000000
# mean           3.899800   520.126000   755.861000
# std            0.522353   275.424626   263.792233
# min            3.000000    50.000000   300.000000
# 25%            3.500000   285.000000   533.750000
# 50%            3.900000   513.000000   769.500000
# 75%            4.300000   762.500000   981.250000
# max            4.800000   997.000000  1200.000000

# %%
df.head()
# Out:
#   Restaurant_Name  Aggregate_Rating  Votes  Cost Online_Order Cuisines
# 0   Restaurant A0               3.9    232   771          Yes  Chinese
# 1   Restaurant B1               3.3    489  1107           No  Italian
# 2   Restaurant C2               4.1    968   309          Yes   Indian
# 3   Restaurant D3               3.9    879  1177           No  Italian
# 4   Restaurant E4               3.5    683   956           No  Chinese

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Restaurant_Name   1000 non-null   object
#  1   Aggregate_Rating  1000 non-null   float64
#  2   Votes             1000 non-null   int64
#  3   Cost              1000 non-null   int64
#  4   Online_Order      1000 non-null   object
#  5   Cuisines          1000 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 47.0+ KB

# %%
sns.histplot(df["Aggregate_Rating"])
plt.xlabel("Aggregate_Rating")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(df["Votes"])
plt.xlabel("Votes")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(df["Cost"])
plt.xlabel("Cost")
plt.ylabel("Frequency")
plt.show()

# %%
sns.scatterplot(x="Votes", y="Aggregate_Rating", data=df)
plt.show()

# %%
sns.scatterplot(x="Aggregate_Rating", y="Cost", data=df)
plt.show()
